# %% [markdown]
# #0. Instalación e importanción de librerías

# %%
# !pip install pandas==2.0.0
# Out:
# Collecting pandas==2.0.0
#   Downloading pandas-2.0.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 57.5 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas==2.0.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas==2.0.0) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas==2.0.0) (2024.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas==2.0.0) (1.25.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas==2.0.0) (1.16.0)
# Installing collected packages: pandas
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.0.3
#     Uninstalling pandas-2.0.3:
#       Successfully uninstalled pandas-2.0.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.0.3, but you have pandas 2.0.0 which is incompatible.
# Successfully installed pandas-2.0.0

# %%
# Manejo de gráficas
# !pip install scikit-plot
# Out:
# Collecting scikit-plot
#   Downloading scikit_plot-0.3.7-py3-none-any.whl (33 kB)
# Requirement already satisfied: matplotlib>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from scikit-plot) (3.7.1)
# Requirement already satisfied: scikit-learn>=0.18 in /usr/local/lib/python3.10/dist-packages (from scikit-plot) (1.2.2)
# Requirement already satisfied: scipy>=0.9 in /usr/local/lib/python3.10/dist-packages (from scikit-plot) (1.11.4)
# Requirement already satisfied: joblib>=0.10 in /usr/local/lib/python3.10/dist-packages (from scikit-plot) (1.3.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (2.8.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.18->scikit-plot) (3.4.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=1.4.0->scikit-plot) (1.16.0)
# Installing collected packages: scikit-plot
# Successfully installed scikit-plot-0.3.7

# %%
# librería Natural Language Toolkit, usada para trabajar con textos
import nltk
# Punkt permite separar un texto en frases.
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
# Descarga todas las palabras vacias, es decir, aquellas que no aportan nada al significado del texto
# ¿Cuales son esas palabras vacías?

nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
# Instalar stanza para lematizar en español!
# !pip install stanza
# Out:
# Collecting stanza
#   Downloading stanza-1.8.1-py3-none-any.whl (970 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 970.4/970.4 kB 11.9 MB/s eta 0:00:00
# Collecting emoji (from stanza)
#   Downloading emoji-2.11.0-py2.py3-none-any.whl (433 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 433.8/433.8 kB 19.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from stanza) (1.25.2)
# Requirement already satisfied: protobuf>=3.15.0 in /usr/local/lib/python3.10/dist-packages (from stanza) (3.20.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from stanza) (2.31.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from stanza) (3.2.1)
# Requirement already satisfied: toml in /usr/local/lib/python3.10/dist-packages (from stanza) (0.10.2)
# Requirement already satisfied: torch>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from stanza) (2.2.1+cu121)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from stanza) (4.66.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (3.13.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (4.10.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (1.12)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.3.0->stanza)
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 64.4 MB/s eta 0:00:00
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.3.0->stanza)
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 63.2 MB/s eta 0:00:00
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.3.0->stanza)
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 95.4 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.3.0->stanza)
#   Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 2.5 MB/s eta 0:00:00
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.3.0->stanza)
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 3.1 MB/s eta 0:00:00
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.3.0->stanza)
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 13.9 MB/s eta 0:00:00
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.3.0->stanza)
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 30.2 MB/s eta 0:00:00
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.3.0->stanza)
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 8.0 MB/s eta 0:00:00
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.3.0->stanza)
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 4.3 MB/s eta 0:00:00
# Collecting nvidia-nccl-cu12==2.19.3 (from torch>=1.3.0->stanza)
#   Downloading nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 10.5 MB/s eta 0:00:00
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.3.0->stanza)
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 15.4 MB/s eta 0:00:00
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (2.2.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.3.0->stanza)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 85.1 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->stanza) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->stanza) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->stanza) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->stanza) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.3.0->stanza) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.3.0->stanza) (1.3.0)
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, emoji, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, stanza
# Successfully installed emoji-2.11.0 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.1.105 stanza-1.8.1

# %%
# Instalación de librerias
import pandas as pd
import numpy as np
import sys
# !{sys.executable} -m pip install pandas-profiling

import stanza
stanza.download('es', package='ancora', processors='tokenize,mwt,pos,lemma', verbose=True)

import re, string, unicodedata
from nltk import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import LancasterStemmer

from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer, HashingVectorizer
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.svm import SVC
from sklearn.ensemble import BaggingClassifier, RandomForestClassifier, AdaBoostClassifier
from sklearn.naive_bayes import BernoulliNB, MultinomialNB
from sklearn.metrics import classification_report, confusion_matrix, precision_score, recall_score, f1_score, accuracy_score
from sklearn.metrics import ConfusionMatrixDisplay

from sklearn.base import BaseEstimator, ClassifierMixin

import matplotlib.pyplot as plt
# Out:
# Collecting pandas-profiling
#   Downloading pandas_profiling-3.6.6-py2.py3-none-any.whl (324 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 324.4/324.4 kB 7.3 MB/s eta 0:00:00
# Collecting ydata-profiling (from pandas-profiling)
#   Downloading ydata_profiling-4.7.0-py2.py3-none-any.whl (357 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 357.9/357.9 kB 14.6 MB/s eta 0:00:00
# Requirement already satisfied: scipy<1.12,>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling->pandas-profiling) (1.11.4)
# Requirement already satisfied: pandas!=1.4.0,<3,>1.1 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling->pandas-profiling) (2.0.0)
# Requirement already satisfied: matplotlib<3.9,>=3.2 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling->pandas-profiling) (3.7.1)
# Requirement already satisfied: pydantic>=2 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling->pandas-profiling) (2.6.4)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling->pandas-profiling) (6.0.1)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling->pandas-profiling) (3.1.3)
# Collecting visions[type_image_path]<0.7.7,>=0.7.5 (from ydata-profiling->pandas-profiling)
#   Downloading visions-0.7.6-py3-none-any.whl (104 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.8/104.8 kB 10.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy<2,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling->pandas-profiling) (1.25.2)
# Collecting htmlmin==0.1.12 (from ydata-profiling->pandas-profiling)
#   Downloading htmlmin-0.1.12.tar.gz (19 kB)
#   Preparing metadata (setup.py) ... done
# Collecting phik<0.13,>=0.11.1 (from ydata-profiling->pandas-profiling)
#   Downloading phik-0.12.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (686 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 686.1/686.1 kB 18.7 MB/s eta 0:00:00
# Requirement already satisfied: requests<3,>=2.24.0 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling->pandas-profiling) (2.31.0)
# Requirement already satisfied: tqdm<5,>=4.48.2 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling->pandas-profiling) (4.66.2)
# Collecting seaborn<0.13,>=0.10.1 (from ydata-profiling->pandas-profiling)
#   Downloading seaborn-0.12.2-py3-none-any.whl (293 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.3/293.3 kB 23.4 MB/s eta 0:00:00
# Collecting multimethod<2,>=1.4 (from ydata-profiling->pandas-profiling)
#   Downloading multimethod-1.11.2-py3-none-any.whl (10 kB)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling->pandas-profiling) (0.14.1)
# Collecting typeguard<5,>=4.1.2 (from ydata-profiling->pandas-profiling)
#   Downloading typeguard-4.2.1-py3-none-any.whl (34 kB)
# Collecting imagehash==4.3.1 (from ydata-profiling->pandas-profiling)
#   Downloading ImageHash-4.3.1-py2.py3-none-any.whl (296 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 20.3 MB/s eta 0:00:00
# Requirement already satisfied: wordcloud>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling->pandas-profiling) (1.9.3)
# Collecting dacite>=1.8 (from ydata-profiling->pandas-profiling)
#   Downloading dacite-1.8.1-py3-none-any.whl (14 kB)
# Requirement already satisfied: numba<1,>=0.56.0 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling->pandas-profiling) (0.58.1)
# Requirement already satisfied: PyWavelets in /usr/local/lib/python3.10/dist-packages (from imagehash==4.3.1->ydata-profiling->pandas-profiling) (1.6.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from imagehash==4.3.1->ydata-profiling->pandas-profiling) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2<3.2,>=2.11.1->ydata-profiling->pandas-profiling) (2.1.5)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.9,>=3.2->ydata-profiling->pandas-profiling) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.9,>=3.2->ydata-profiling->pandas-profiling) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.9,>=3.2->ydata-profiling->pandas-profiling) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.9,>=3.2->ydata-profiling->pandas-profiling) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.9,>=3.2->ydata-profiling->pandas-profiling) (24.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.9,>=3.2->ydata-profiling->pandas-profiling) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.9,>=3.2->ydata-profiling->pandas-profiling) (2.8.2)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba<1,>=0.56.0->ydata-profiling->pandas-profiling) (0.41.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas!=1.4.0,<3,>1.1->ydata-profiling->pandas-profiling) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas!=1.4.0,<3,>1.1->ydata-profiling->pandas-profiling) (2024.1)
# Requirement already satisfied: joblib>=0.14.1 in /usr/local/lib/python3.10/dist-packages (from phik<0.13,>=0.11.1->ydata-profiling->pandas-profiling) (1.3.2)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2->ydata-profiling->pandas-profiling) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2->ydata-profiling->pandas-profiling) (2.16.3)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2->ydata-profiling->pandas-profiling) (4.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.24.0->ydata-profiling->pandas-profiling) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.24.0->ydata-profiling->pandas-profiling) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.24.0->ydata-profiling->pandas-profiling) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.24.0->ydata-profiling->pandas-profiling) (2024.2.2)
# Requirement already satisfied: patsy>=0.5.4 in /usr/local/lib/python3.10/dist-packages (from statsmodels<1,>=0.13.2->ydata-profiling->pandas-profiling) (0.5.6)
# Requirement already satisfied: attrs>=19.3.0 in /usr/local/lib/python3.10/dist-packages (from visions[type_image_path]<0.7.7,>=0.7.5->ydata-profiling->pandas-profiling) (23.2.0)
# Requirement already satisfied: networkx>=2.4 in /usr/local/lib/python3.10/dist-packages (from visions[type_image_path]<0.7.7,>=0.7.5->ydata-profiling->pandas-profiling) (3.2.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from patsy>=0.5.4->statsmodels<1,>=0.13.2->ydata-profiling->pandas-profiling) (1.16.0)
# Building wheels for collected packages: htmlmin
#   Building wheel for htmlmin (setup.py) ... done
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27080 sha256=5a93651d4979b1ecf106f540c5fd25736680df8e0db87b615338ca8faccaa665
#   Stored in directory: /root/.cache/pip/wheels/dd/91/29/a79cecb328d01739e64017b6fb9a1ab9d8cb1853098ec5966d
# Successfully built htmlmin
# Installing collected packages: htmlmin, typeguard, multimethod, dacite, imagehash, visions, seaborn, phik, ydata-profiling, pandas-profiling
#   Attempting uninstall: seaborn
#     Found existing installation: seaborn 0.13.1
#     Uninstalling seaborn-0.13.1:
#       Successfully uninstalled seaborn-0.13.1
# Successfully installed dacite-1.8.1 htmlmin-0.1.12 imagehash-4.3.1 multimethod-1.11.2 pandas-profiling-3.6.6 phik-0.12.4 seaborn-0.12.2 typeguard-4.2.1 visions-0.7.6 ydata-profiling-4.7.0
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.8.0.json:   0%|   …
# INFO:stanza:Downloaded file to /root/stanza_resources/resources.json
# INFO:stanza:Downloading these customized packages for language: es (Spanish)...
# =====================================
# | Processor       | Package         |
# -------------------------------------
# | tokenize        | ancora          |
# | mwt             | ancora          |
# | pos             | ancora_charlm   |
# | lemma           | ancora_nocharlm |
# | forward_charlm  | newswiki        |
# | pretrain        | conll17         |
# | backward_charlm | newswiki        |
# =====================================
# Downloading https://huggingface.co/stanfordnlp/stanza-es/resolve/v1.8.0/models/tokenize/ancora.pt:   0%|      …
# INFO:stanza:Downloaded file to /root/stanza_resources/es/tokenize/ancora.pt
# Downloading https://huggingface.co/stanfordnlp/stanza-es/resolve/v1.8.0/models/mwt/ancora.pt:   0%|          |…
# INFO:stanza:Downloaded file to /root/stanza_resources/es/mwt/ancora.pt
# Downloading https://huggingface.co/stanfordnlp/stanza-es/resolve/v1.8.0/models/pos/ancora_charlm.pt:   0%|    …
# INFO:stanza:Downloaded file to /root/stanza_resources/es/pos/ancora_charlm.pt
# Downloading https://huggingface.co/stanfordnlp/stanza-es/resolve/v1.8.0/models/lemma/ancora_nocharlm.pt:   0%|…
# INFO:stanza:Downloaded file to /root/stanza_resources/es/lemma/ancora_nocharlm.pt
# Downloading https://huggingface.co/stanfordnlp/stanza-es/resolve/v1.8.0/models/forward_charlm/newswiki.pt:   0…
# INFO:stanza:Downloaded file to /root/stanza_resources/es/forward_charlm/newswiki.pt
# Downloading https://huggingface.co/stanfordnlp/stanza-es/resolve/v1.8.0/models/pretrain/conll17.pt:   0%|     …
# INFO:stanza:Downloaded file to /root/stanza_resources/es/pretrain/conll17.pt
# Downloading https://huggingface.co/stanfordnlp/stanza-es/resolve/v1.8.0/models/backward_charlm/newswiki.pt:   …
# INFO:stanza:Downloaded file to /root/stanza_resources/es/backward_charlm/newswiki.pt
# INFO:stanza:Finished downloading models and saved to /root/stanza_resources

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 2.0.0

# %% [markdown]
# #1. Perfilamiento de los datos y procesamiento de texto

# %% [markdown]
# ## 1.1  Lectura de los datos

# %%
# Uso de la libreria pandas para la lectura de archivos
data=pd.read_csv('/content/tipo2_entrenamiento_estudiantes.csv')
# Asignación a una nueva variable de los datos leidos
data_t=data

# %%
data_t
# Out:
#                                                  Review  Class
# 0     Muy buena atención y aclaración de dudas por p...      5
# 1     Buen hotel si están obligados a estar cerca de...      3
# 2     Es un lugar muy lindo para fotografías, visite...      5
# 3     Abusados con la factura de alimentos siempre s...      3
# 4     Tuvimos un par de personas en el grupo que rea...      3
# ...                                                 ...    ...
# 7870  Me parece buen sistema, agiliza el transporte,...      4
# 7871  Fue una escapada de un día desde el complejo, ...      4
# 7872  La Plaza de la Revolución es un lugar emblemát...      3
# 7873  Es la segunda ocasión que me quedo en los cuar...      1
# 7874  Llegamos por casualidad a Los Mercaderes, un g...      5
#
# [7875 rows x 2 columns]

# %%
data_t.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7875 entries, 0 to 7874
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Review  7875 non-null   object
#  1   Class   7875 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 123.2+ KB

# %% [markdown]
# ## 1.2 Entendimiento de los Datos

# %% [markdown]
# Contamos la cantidad de palabras que hay por review, así como la longitud máxima y minima por palabra

# %%
from scipy import stats as st

textos = data_t.copy()
textos['Conteo'] = [len(x) for x in textos['Review']]
textos['Max'] = [[max([len(x) for x in i.split(' ')])][0] for i in textos['Review']]
textos['Min'] = [[min([len(x) for x in i.split(' ')])][0] for i in textos['Review']]

# %%
textos
# Out:
#                                                  Review  Class  Conteo  Max
# 0     Muy buena atención y aclaración de dudas por p...      5     252   20  \
# 1     Buen hotel si están obligados a estar cerca de...      3     297   13
# 2     Es un lugar muy lindo para fotografías, visite...      5     104   12
# 3     Abusados con la factura de alimentos siempre s...      3     422   14
# 4     Tuvimos un par de personas en el grupo que rea...      3     419   14
# ...                                                 ...    ...     ...  ...
# 7870  Me parece buen sistema, agiliza el transporte,...      4     113   11
# 7871  Fue una escapada de un día desde el complejo, ...      4     261   12
# 7872  La Plaza de la Revolución es un lugar emblemát...      3     777   14
# 7873  Es la segunda ocasión que me quedo en los cuar...      1     651   12
# 7874  Llegamos por casualidad a Los Mercaderes, un g...      5     252   11
#
#       Min
# 0       0
# 1       1
# 2       1
# 3       1
# 4       1
# ...   ...
# 7870    2
# 7871    2
# 7872    1
# 7873    0
# 7874    1
#
# [7875 rows x 5 columns]

# %%
textos['Promedio'] = textos['Conteo'] / textos['Review'].str.split().apply(len)

# %%
print("Valor máximo de longitud de palabras:", textos['Max'].max())
print("Valor mínimo de longitud de palabras:", textos['Min'].min())
print("Promedio de longitud de palabras:", textos['Promedio'].mean())
# Out:
# Valor máximo de longitud de palabras: 76
# Valor mínimo de longitud de palabras: 0
# Promedio de longitud de palabras: 5.817592907560202

# %% [markdown]
# ## 1.3 Preprocesado de los datos

# %% [markdown]
# ### 1.3.1 Funciones para la limpieza de los datos

# %% [markdown]
# Definimos las funciones a utilizar para la limpieza de los datos.

# %%
def remove_non_ascii(words):
    """Remove non-ASCII characters from list of tokenized words"""
    new_words = []
    for word in words:
        if word is not None:
          new_word = unicodedata.normalize('NFKD', word).encode('ascii', 'ignore').decode('utf-8', 'ignore')
          new_words.append(new_word)
    return new_words

def to_lowercase(words):
    """Convert all characters to lowercase from list of tokenized words"""
    new_words = []
    for word in words:
        if word is not None:
            new_word = word.lower()
            new_words.append(new_word)
    return new_words

import string

def remove_punctuation(words):
    """Remove punctuation from list of tokenized words"""
    filtered_tokens = [token for token in words if token not in string.punctuation]
    return filtered_tokens

def remove_stopwords(words):
    """Remove stop words from list of tokenized words"""
    stop_words = set(stopwords.words('spanish'))
    new_words = []
    for word in words:
        if word not in stop_words:
            new_words.append(word)
    return new_words

def preprocessing(words):
    words = remove_stopwords(words)
    words = to_lowercase(words)
    words = remove_punctuation(words)
    words = remove_non_ascii(words)
    return words

# %% [markdown]
# ###1.3.2 Tokenización

# %%
data_t['words'] = data_t['Review'].apply(word_tokenize)
data_t.head()
# Out:
#                                               Review  Class
# 0  Muy buena atención y aclaración de dudas por p...      5  \
# 1  Buen hotel si están obligados a estar cerca de...      3
# 2  Es un lugar muy lindo para fotografías, visite...      5
# 3  Abusados con la factura de alimentos siempre s...      3
# 4  Tuvimos un par de personas en el grupo que rea...      3
#
#                                                words
# 0  [Muy, buena, atención, y, aclaración, de, duda...
# 1  [Buen, hotel, si, están, obligados, a, estar, ...
# 2  [Es, un, lugar, muy, lindo, para, fotografías,...
# 3  [Abusados, con, la, factura, de, alimentos, si...
# 4  [Tuvimos, un, par, de, personas, en, el, grupo...

# %% [markdown]
# Eliminamos valores nulos en caso de que existan

# %%
data_t['words'].dropna()
# Out:
# 0       [Muy, buena, atención, y, aclaración, de, duda...
# 1       [Buen, hotel, si, están, obligados, a, estar, ...
# 2       [Es, un, lugar, muy, lindo, para, fotografías,...
# 3       [Abusados, con, la, factura, de, alimentos, si...
# 4       [Tuvimos, un, par, de, personas, en, el, grupo...
#                               ...
# 7870    [Me, parece, buen, sistema, ,, agiliza, el, tr...
# 7871    [Fue, una, escapada, de, un, día, desde, el, c...
# 7872    [La, Plaza, de, la, Revolución, es, un, lugar,...
# 7873    [Es, la, segunda, ocasión, que, me, quedo, en,...
# 7874    [Llegamos, por, casualidad, a, Los, Mercaderes...
# Name: words, Length: 7875, dtype: object

# %%
data_t.shape
# Out:
# (7875, 3)

# %%
 data_t['words'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 7875 entries, 0 to 7874
# Series name: words
# Non-Null Count  Dtype
# --------------  -----
# 7875 non-null   object
# dtypes: object(1)
# memory usage: 61.6+ KB

# %% [markdown]
# ### 1.3.3 Stopwords, minusculas, signos de puntuación

# %% [markdown]
# Aplicamos la limpieza de los datos:
# - Eliminamos las palabras vacias
# - Convertimos todo a minusculas.
# - Eliminamos los signos de puntuación
# - Quitamos caracteres no ASCII (Simbolos especiales, emojis, etc)

# %%
data_t['words1']=data_t['words'].apply(preprocessing) #Aplica la eliminación del ruido

data_t.head()
# Out:
#                                               Review  Class
# 0  Muy buena atención y aclaración de dudas por p...      5  \
# 1  Buen hotel si están obligados a estar cerca de...      3
# 2  Es un lugar muy lindo para fotografías, visite...      5
# 3  Abusados con la factura de alimentos siempre s...      3
# 4  Tuvimos un par de personas en el grupo que rea...      3
#
#                                                words
# 0  [Muy, buena, atención, y, aclaración, de, duda...  \
# 1  [Buen, hotel, si, están, obligados, a, estar, ...
# 2  [Es, un, lugar, muy, lindo, para, fotografías,...
# 3  [Abusados, con, la, factura, de, alimentos, si...
# 4  [Tuvimos, un, par, de, personas, en, el, grupo...
#
#                                               words1
# 0  [muy, buena, atencion, aclaracion, dudas, part...
# 1  [buen, hotel, si, obligados, cerca, centro, co...
# 2  [es, lugar, lindo, fotografias, visiten, selin...
# 3  [abusados, factura, alimentos, siempre, echan,...
# 4  [tuvimos, par, personas, grupo, realmente, que...

# %% [markdown]
# ###1.3.4 Lematización

# %%
lemmatizer_es = stanza.Pipeline(lang='es', processors='tokenize,mwt,pos,lemma', use_gpu=True)

def lemmatize_spanish(words):
    doc = lemmatizer_es(words)
    lemmas = [word.lemma for sent in doc.sentences for word in sent.words]
    return lemmas


import string

def eliminar_puntuacion(words):
    filtered_tokens = [token for token in words if token not in string.punctuation]
    return filtered_tokens


data_t.head()
# Out:
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.8.0.json:   0%|   …
# INFO:stanza:Downloaded file to /root/stanza_resources/resources.json
# INFO:stanza:Loading these models for language: es (Spanish):
# ===============================
# | Processor | Package         |
# -------------------------------
# | tokenize  | ancora          |
# | mwt       | ancora          |
# | pos       | ancora_charlm   |
# | lemma     | ancora_nocharlm |
# ===============================
#
# INFO:stanza:Using device: cuda
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: mwt
# INFO:stanza:Loading: pos
# INFO:stanza:Loading: lemma
# INFO:stanza:Done loading processors!
#                                               Review  Class
# 0  Muy buena atención y aclaración de dudas por p...      5  \
# 1  Buen hotel si están obligados a estar cerca de...      3
# 2  Es un lugar muy lindo para fotografías, visite...      5
# 3  Abusados con la factura de alimentos siempre s...      3
# 4  Tuvimos un par de personas en el grupo que rea...      3
#
#                                                words
# 0  [Muy, buena, atención, y, aclaración, de, duda...  \
# 1  [Buen, hotel, si, están, obligados, a, estar, ...
# 2  [Es, un, lugar, muy, lindo, para, fotografías,...
# 3  [Abusados, con, la, factura, de, alimentos, si...
# 4  [Tuvimos, un, par, de, personas, en, el, grupo...
#
#                                               words1
# 0  [muy, buena, atencion, aclaracion, dudas, part...
# 1  [buen, hotel, si, obligados, cerca, centro, co...
# 2  [es, lugar, lindo, fotografias, visiten, selin...
# 3  [abusados, factura, alimentos, siempre, echan,...
# 4  [tuvimos, par, personas, grupo, realmente, que...

# %%
data_t['words1'] = data_t['words1'].apply(lambda x: ' '.join(map(str, x)))

# %%
data_t['lemma'] = data_t['words1'].apply(lemmatize_spanish) #Aplica lematización y Eliminación de Prefijos y Sufijos.
data_t
# Out:
#                                                  Review  Class
# 0     Muy buena atención y aclaración de dudas por p...      5  \
# 1     Buen hotel si están obligados a estar cerca de...      3
# 2     Es un lugar muy lindo para fotografías, visite...      5
# 3     Abusados con la factura de alimentos siempre s...      3
# 4     Tuvimos un par de personas en el grupo que rea...      3
# ...                                                 ...    ...
# 7870  Me parece buen sistema, agiliza el transporte,...      4
# 7871  Fue una escapada de un día desde el complejo, ...      4
# 7872  La Plaza de la Revolución es un lugar emblemát...      3
# 7873  Es la segunda ocasión que me quedo en los cuar...      1
# 7874  Llegamos por casualidad a Los Mercaderes, un g...      5
#
#                                                   words
# 0     [Muy, buena, atención, y, aclaración, de, duda...  \
# 1     [Buen, hotel, si, están, obligados, a, estar, ...
# 2     [Es, un, lugar, muy, lindo, para, fotografías,...
# 3     [Abusados, con, la, factura, de, alimentos, si...
# 4     [Tuvimos, un, par, de, personas, en, el, grupo...
# ...                                                 ...
# 7870  [Me, parece, buen, sistema, ,, agiliza, el, tr...
# 7871  [Fue, una, escapada, de, un, día, desde, el, c...
# 7872  [La, Plaza, de, la, Revolución, es, un, lugar,...
# 7873  [Es, la, segunda, ocasión, que, me, quedo, en,...
# 7874  [Llegamos, por, casualidad, a, Los, Mercaderes...
#
#                                                  words1
# 0     muy buena atencion aclaracion dudas parte seno...  \
# 1     buen hotel si obligados cerca centro convencio...
# 2     es lugar lindo fotografias visiten selina musi...
# 3     abusados factura alimentos siempre echan culpa...
# 4     tuvimos par personas grupo realmente queriamos...
# ...                                                 ...
# 7870  me parece buen sistema agiliza transporte cone...
# 7871  fue escapada dia complejo grupo turistas guias...
# 7872  la plaza revolucion lugar emblematico identifi...
# 7873  es segunda ocasion quedo cuartos area jardin c...
# 7874  llegamos casualidad los mercaderes grupo grand...
#
#                                                   lemma
# 0     [mucho, buen, atencion, aclaracion, duda, part...
# 1     [buen, hotel, si, obligado, cerca, centro, con...
# 2     [ser, lugar, lindo, fotografia, visitar, selin...
# 3     [abusado, factura, alimento, siempre, echar, c...
# 4     [tener, par, persona, grupo, realmente, querer...
# ...                                                 ...
# 7870  [yo, parecer, buen, sistema, agilizar, transpo...
# 7871  [ser, escapada, dia, complejo, grupo, turista,...
# 7872  [el, plaza, revolucion, lugar, emblematico, id...
# 7873  [ser, segundo, ocasion, quedar, cuarto, areo, ...
# 7874  [llegar, casualidad, el, mercader, grupo, gran...
#
# [7875 rows x 5 columns]

# %%
data_t
# Out:
#                                                  Review  Class
# 0     Muy buena atención y aclaración de dudas por p...      5  \
# 1     Buen hotel si están obligados a estar cerca de...      3
# 2     Es un lugar muy lindo para fotografías, visite...      5
# 3     Abusados con la factura de alimentos siempre s...      3
# 4     Tuvimos un par de personas en el grupo que rea...      3
# ...                                                 ...    ...
# 7870  Me parece buen sistema, agiliza el transporte,...      4
# 7871  Fue una escapada de un día desde el complejo, ...      4
# 7872  La Plaza de la Revolución es un lugar emblemát...      3
# 7873  Es la segunda ocasión que me quedo en los cuar...      1
# 7874  Llegamos por casualidad a Los Mercaderes, un g...      5
#
#                                                   words
# 0     [Muy, buena, atención, y, aclaración, de, duda...  \
# 1     [Buen, hotel, si, están, obligados, a, estar, ...
# 2     [Es, un, lugar, muy, lindo, para, fotografías,...
# 3     [Abusados, con, la, factura, de, alimentos, si...
# 4     [Tuvimos, un, par, de, personas, en, el, grupo...
# ...                                                 ...
# 7870  [Me, parece, buen, sistema, ,, agiliza, el, tr...
# 7871  [Fue, una, escapada, de, un, día, desde, el, c...
# 7872  [La, Plaza, de, la, Revolución, es, un, lugar,...
# 7873  [Es, la, segunda, ocasión, que, me, quedo, en,...
# 7874  [Llegamos, por, casualidad, a, Los, Mercaderes...
#
#                                                  words1
# 0     muy buena atencion aclaracion dudas parte seno...  \
# 1     buen hotel si obligados cerca centro convencio...
# 2     es lugar lindo fotografias visiten selina musi...
# 3     abusados factura alimentos siempre echan culpa...
# 4     tuvimos par personas grupo realmente queriamos...
# ...                                                 ...
# 7870  me parece buen sistema agiliza transporte cone...
# 7871  fue escapada dia complejo grupo turistas guias...
# 7872  la plaza revolucion lugar emblematico identifi...
# 7873  es segunda ocasion quedo cuartos area jardin c...
# 7874  llegamos casualidad los mercaderes grupo grand...
#
#                                                   lemma
# 0     [mucho, buen, atencion, aclaracion, duda, part...
# 1     [buen, hotel, si, obligado, cerca, centro, con...
# 2     [ser, lugar, lindo, fotografia, visitar, selin...
# 3     [abusado, factura, alimento, siempre, echar, c...
# 4     [tener, par, persona, grupo, realmente, querer...
# ...                                                 ...
# 7870  [yo, parecer, buen, sistema, agilizar, transpo...
# 7871  [ser, escapada, dia, complejo, grupo, turista,...
# 7872  [el, plaza, revolucion, lugar, emblematico, id...
# 7873  [ser, segundo, ocasion, quedar, cuarto, areo, ...
# 7874  [llegar, casualidad, el, mercader, grupo, gran...
#
# [7875 rows x 5 columns]

# %% [markdown]
# ### 1.3.5 Más stopwords

# %% [markdown]
# Definimos más stop words.

# %%
DETERMINANTES = [
    "el",
    "la",
    "los",
    "las",
    "un",
    "una",
    "unos",
    "unas",
    "esta",
    "estas",
    "este",
    "estos",
    "esa",
    "esas",
    "ese",
    "esos",
    "aquel",
    "aquella",
    "aquellas",
    "aquellos",
    "mi",
    "tu",
    "su",
    "mis",
    "tus",
    "sus",
    "nuestro",
    "nuestra",
    "nuestros",
    "nuestras",
    "vuestro",
    "vuestra",
    "vuestros",
    "vuestras",
    "su",
    "sus",
    "cuyo",
    "cuya",
    "cuyos",
    "cuyas",
    "cuánto",
    "cuántos",
    "cuánta",
    "cuántas",
    "qué",
    "tan",
    "menos",
    "más",
    "algún",
    "alguna",
    "algunos",
    "algunas",
    "ningún",
    "ninguna",
    "ningunos",
    "ningunas",
]

PREPOSICIONES = [
    "a",
    "ante",
    "bajo",
    "cabe",
    "con",
    "contra",
    "de",
    "desde",
    "durante",
    "en",
    "entre",
    "hacia",
    "hasta",
    "mediante",
    "para",
    "por",
    "según",
    "sin",
    "so",
    "sobre",
    "tras",
    "versus",
    "vía",
]

PRONOMBRES = [
    "yo",
    "tú",
    "vos",
    "vo",
    "él",
    "ella",
    "ello",
    "elle",
    "usted",
    "nosotros",
    "nosotras",
    "nosotres",
    "vosotros",
    "vosotras",
    "vosotres",
    "ellos",
    "ellas",
    "ustedes",
    "elles",
    "mí",
    "ti",
    "sí",
    "consigo",
]

CONJUNCIONES = [
    "y",
    "ni",
    "sino",
    "tanto",
    "como",
    "que",
    "pero",
    "mas",
    "empero",
    "mientras",
    "o",
    "bien",
    "ya",
]

default_stopwords = list(set(DETERMINANTES + PREPOSICIONES + PRONOMBRES + CONJUNCIONES))

# %% [markdown]
# Eliminamos las stopwords

# %%
data_t['lemma_2'] = data_t['lemma'].apply(lambda x: [word for word in x if word not in default_stopwords])

# %% [markdown]
# Eliminamos los numeros

# %%
# Eliminar números
data_t['lemma_2'] = data_t['lemma_2'].apply(lambda x: [word for word in x if not word.isdigit()])

# %%
data_t
# Out:
#                                                  Review  Class
# 0     Muy buena atención y aclaración de dudas por p...      5  \
# 1     Buen hotel si están obligados a estar cerca de...      3
# 2     Es un lugar muy lindo para fotografías, visite...      5
# 3     Abusados con la factura de alimentos siempre s...      3
# 4     Tuvimos un par de personas en el grupo que rea...      3
# ...                                                 ...    ...
# 7870  Me parece buen sistema, agiliza el transporte,...      4
# 7871  Fue una escapada de un día desde el complejo, ...      4
# 7872  La Plaza de la Revolución es un lugar emblemát...      3
# 7873  Es la segunda ocasión que me quedo en los cuar...      1
# 7874  Llegamos por casualidad a Los Mercaderes, un g...      5
#
#                                                   words
# 0     [Muy, buena, atención, y, aclaración, de, duda...  \
# 1     [Buen, hotel, si, están, obligados, a, estar, ...
# 2     [Es, un, lugar, muy, lindo, para, fotografías,...
# 3     [Abusados, con, la, factura, de, alimentos, si...
# 4     [Tuvimos, un, par, de, personas, en, el, grupo...
# ...                                                 ...
# 7870  [Me, parece, buen, sistema, ,, agiliza, el, tr...
# 7871  [Fue, una, escapada, de, un, día, desde, el, c...
# 7872  [La, Plaza, de, la, Revolución, es, un, lugar,...
# 7873  [Es, la, segunda, ocasión, que, me, quedo, en,...
# 7874  [Llegamos, por, casualidad, a, Los, Mercaderes...
#
#                                                  words1
# 0     muy buena atencion aclaracion dudas parte seno...  \
# 1     buen hotel si obligados cerca centro convencio...
# 2     es lugar lindo fotografias visiten selina musi...
# 3     abusados factura alimentos siempre echan culpa...
# 4     tuvimos par personas grupo realmente queriamos...
# ...                                                 ...
# 7870  me parece buen sistema agiliza transporte cone...
# 7871  fue escapada dia complejo grupo turistas guias...
# 7872  la plaza revolucion lugar emblematico identifi...
# 7873  es segunda ocasion quedo cuartos area jardin c...
# 7874  llegamos casualidad los mercaderes grupo grand...
#
#                                                   lemma
# 0     [mucho, buen, atencion, aclaracion, duda, part...  \
# 1     [buen, hotel, si, obligado, cerca, centro, con...
# 2     [ser, lugar, lindo, fotografia, visitar, selin...
# 3     [abusado, factura, alimento, siempre, echar, c...
# 4     [tener, par, persona, grupo, realmente, querer...
# ...                                                 ...
# 7870  [yo, parecer, buen, sistema, agilizar, transpo...
# 7871  [ser, escapada, dia, complejo, grupo, turista,...
# 7872  [el, plaza, revolucion, lugar, emblematico, id...
# 7873  [ser, segundo, ocasion, quedar, cuarto, areo, ...
# 7874  [llegar, casualidad, el, mercader, grupo, gran...
#
#                                                 lemma_2
# 0     [mucho, buen, atencion, aclaracion, duda, part...
# 1     [buen, hotel, si, obligado, cerca, centro, con...
# 2     [ser, lugar, lindo, fotografia, visitar, selin...
# 3     [abusado, factura, alimento, siempre, echar, c...
# 4     [tener, par, persona, grupo, realmente, querer...
# ...                                                 ...
# 7870  [parecer, buen, sistema, agilizar, transporte,...
# 7871  [ser, escapada, dia, complejo, grupo, turista,...
# 7872  [plaza, revolucion, lugar, emblematico, identi...
# 7873  [ser, segundo, ocasion, quedar, cuarto, areo, ...
# 7874  [llegar, casualidad, mercader, grupo, grande, ...
#
# [7875 rows x 6 columns]

# %% [markdown]
# ### 1.3.6 Exportar los datos preparados

# %%
data_t[['Review', 'lemma_2', 'Class']].to_csv('datos_preparados.csv', index=False)

# %% [markdown]
# ## 1.4 Transformación de los datos

# %% [markdown]
# Transformamos las variables categoricas en variables numéricas, un proceso conocido como codificación one-hot

# %%
data_t['datos'] = data_t['lemma_2'].apply(lambda x: ' '.join(map(str, x)))
X_data, y_data = data_t['datos'],data_t['Class']
y_data = pd.get_dummies(y_data)
y_data
# Out:
#           1      2      3      4      5
# 0     False  False  False  False   True
# 1     False  False   True  False  False
# 2     False  False  False  False   True
# 3     False  False   True  False  False
# 4     False  False   True  False  False
# ...     ...    ...    ...    ...    ...
# 7870  False  False  False   True  False
# 7871  False  False  False   True  False
# 7872  False  False   True  False  False
# 7873   True  False  False  False  False
# 7874  False  False  False  False   True
#
# [7875 rows x 5 columns]

# %% [markdown]
#  Transformación de los datos de texto en X_data a una representación numérica utilizando la técnica TF-IDF (Term Frequency-Inverse Document Frequency).

# %%
tf_idf = TfidfVectorizer()
X_tf_idf = tf_idf.fit_transform(X_data)
print(X_tf_idf.shape)
X_tf_nv= X_tf_idf.todense()
# Out:
# (7875, 16190)

# %% [markdown]
# # 2. Modelado y evaluación

# %% [markdown]
# Observamos que hay uno sobre representación de la clase 5 y una baja representación de la clase 1. Por ello, agregamos el parámetro class_weight='balanced' a nuestros modelos

# %%
print(y_data.value_counts(normalize=True))
# Out:
# 1      2      3      4      5
# False  False  False  False  True     0.299810
#                      True   False    0.251048
#               True   False  False    0.199873
#        True   False  False  False    0.150476
# True   False  False  False  False    0.098794
# Name: proportion, dtype: float64

# %% [markdown]
# ## 2.0 División de los datos

# %% [markdown]
# Dividimos los datos del conjunto en dos partes. Reservamos el 20% de los datos para testear el modelo.

# %%
y_data_1d = y_data.idxmax(axis=1)
X_train, X_test, Y_train, Y_test = train_test_split(X_tf_idf, y_data_1d, test_size=0.2, random_state=0, stratify=y_data_1d)

# %% [markdown]
# ## 2.1 Implementación SVC (Henry Santiago Antolinez - 202121785 )

# %%
model = SVC(kernel='rbf', class_weight='balanced')

modelo = model.fit(X_train, Y_train)

# Predict using the SVM model
y_pred_svc = model.predict(X_test)
cm = confusion_matrix(Y_test, y_pred_svc)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=modelo.classes_)
disp.plot(cmap=plt.cm.Blues)

plt.show()

# %%
print('Exactitud: %.2f' % accuracy_score(Y_test, y_pred_svc))
print("Recall: {}".format(recall_score(Y_test, y_pred_svc, average='macro')))
print("Precisión: {}".format(precision_score(Y_test, y_pred_svc, average='macro')))
print("Puntuación F1: {}".format(f1_score(Y_test, y_pred_svc, average='macro')))
# Out:
# Exactitud: 0.51
# Recall: 0.4887245710974524
# Precisión: 0.5175180812339379
# Puntuación F1: 0.4982287905848068

# %%
print(classification_report(Y_test, y_pred_svc))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.59      0.40      0.48       156
#            2       0.46      0.47      0.47       237
#            3       0.45      0.45      0.45       315
#            4       0.43      0.53      0.48       395
#            5       0.65      0.59      0.62       472
#
#     accuracy                           0.51      1575
#    macro avg       0.52      0.49      0.50      1575
# weighted avg       0.52      0.51      0.51      1575

# %% [markdown]
# Guardamos el modelo para usarlo durante el etiquetado de los datos.

# %%
import pickle

# save
with open('model.pkl','wb') as f:
    pickle.dump(modelo,f)

# %% [markdown]
# Busqueda de hiperparametros

# %%
# explicitly require this experimental feature
from sklearn.experimental import enable_halving_search_cv # noqa
# now you can import normally from model_selection
from sklearn.model_selection import HalvingGridSearchCV

# %%
param_grid = {
   'C': np.logspace(-3, 3, 7), # Valores de regularización (inverso de C)
   'gamma': np.logspace(-3, 3, 7), # Parámetro gamma para el kernel RBF
}

# %%
model = SVC(kernel='rbf', class_weight='balanced')

grid_search = HalvingGridSearchCV(estimator=model, param_grid=param_grid, cv=5, scoring='f1_macro', n_jobs=-1)
grid_search.fit(X_train, Y_train)

print("Mejores hiperparámetros: ", grid_search.best_params_)
model = grid_search.best_estimator_

# Predecir usando el modelo SVM
y_pred = model.predict(X_test)

# Calcular la matriz de confusión
cm = confusion_matrix(Y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=model.classes_)
disp.plot(cmap=plt.cm.Blues)
plt.show()
# Out:
# Mejores hiperparámetros:  {'C': 10.0, 'gamma': 0.09999999999999999}

# %%
print('Exactitud: %.2f' % accuracy_score(Y_test, y_pred))
print("Recall: {}".format(recall_score(Y_test, y_pred, average='macro')))
print("Precisión: {}".format(precision_score(Y_test, y_pred, average='macro')))
print("Puntuación F1: {}".format(f1_score(Y_test, y_pred, average='macro')))
# Out:
# Exactitud: 0.49
# Recall: 0.4747318303046688
# Precisión: 0.47651882698063047
# Puntuación F1: 0.4752980130927466

# %%
print(classification_report(Y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.49      0.48      0.48       156
#            2       0.43      0.43      0.43       237
#            3       0.41      0.43      0.42       315
#            4       0.41      0.44      0.42       395
#            5       0.64      0.59      0.62       472
#
#     accuracy                           0.49      1575
#    macro avg       0.48      0.47      0.48      1575
# weighted avg       0.49      0.49      0.49      1575

# %% [markdown]
# ## 2.2 Implementación MLPClassifier (Henry Santiago Antolinez - 202121785)

# %%
from sklearn.neural_network import MLPClassifier

# %%
classifier = MLPClassifier(hidden_layer_sizes=(150,100,50), max_iter=300,activation = 'relu',solver='adam',random_state=1)

# %%
modelo = classifier.fit(X_train, Y_train)

y_pred_mlp = classifier.predict(X_test)
cm = confusion_matrix(Y_test, y_pred_mlp)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=modelo.classes_)
disp.plot(cmap=plt.cm.Blues)

plt.show()

# %%
print('Exactitud: %.2f' % accuracy_score(Y_test, y_pred_mlp))
print("Recall: {}".format(recall_score(Y_test, y_pred_mlp, average='macro')))
print("Precisión: {}".format(precision_score(Y_test, y_pred_mlp, average='macro')))
print("Puntuación F1: {}".format(f1_score(Y_test, y_pred_mlp, average='macro')))
# Out:
# Exactitud: 0.44
# Recall: 0.4255117084874648
# Precisión: 0.43575217690303375
# Puntuación F1: 0.42985210900236515

# %%
print(classification_report(Y_test, y_pred_mlp))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.47      0.41      0.44       156
#            2       0.42      0.40      0.41       237
#            3       0.33      0.37      0.35       315
#            4       0.38      0.38      0.38       395
#            5       0.57      0.57      0.57       472
#
#     accuracy                           0.44      1575
#    macro avg       0.44      0.43      0.43      1575
# weighted avg       0.44      0.44      0.44      1575

# %% [markdown]
# ## 2.3 Implementación Logistic Regression (Juan David Orduz - 202123170)

# %%
# import the class
from sklearn.linear_model import LogisticRegression

# instantiate the model (using the default parameters)
logreg = LogisticRegression(random_state=16, class_weight='balanced', max_iter=10000)

# fit the model with data
logreg.fit(X_train, Y_train)

y_pred_lr = logreg.predict(X_test)

# %%
cm = confusion_matrix(Y_test, y_pred_lr)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=modelo.classes_)
disp.plot(cmap=plt.cm.Blues)

plt.show()

# %%
print('Exactitud: %.2f' % accuracy_score(Y_test, y_pred_lr))
print("Recall: {}".format(recall_score(Y_test, y_pred_lr, average='macro')))
print("Precisión: {}".format(precision_score(Y_test, y_pred_lr, average='macro')))
print("Puntuación F1: {}".format(f1_score(Y_test, y_pred_lr, average='macro')))
# Out:
# Exactitud: 0.49
# Recall: 0.48928783617155214
# Precisión: 0.47525636230429547
# Puntuación F1: 0.4800398178940347

# %%
print(classification_report(Y_test, y_pred_lr))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.49      0.63      0.55       156
#            2       0.42      0.37      0.39       237
#            3       0.41      0.38      0.39       315
#            4       0.43      0.44      0.44       395
#            5       0.64      0.62      0.63       472
#
#     accuracy                           0.49      1575
#    macro avg       0.48      0.49      0.48      1575
# weighted avg       0.49      0.49      0.49      1575

# %% [markdown]
# ## 2.4 Implementación Random Forest (Abel Arismendy - 202020625)

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(n_estimators=10)
clf = clf.fit(X_train, Y_train)

# Predict using the SVM model
y_pred_rf = clf.predict(X_test)
cm = confusion_matrix(Y_test, y_pred_rf)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=modelo.classes_)
disp.plot(cmap=plt.cm.Blues)

plt.show()

# %%
print('Exactitud: %.2f' % accuracy_score(Y_test, y_pred_rf))
print("Recall: {}".format(recall_score(Y_test, y_pred_rf, average='macro')))
print("Precisión: {}".format(precision_score(Y_test, y_pred_rf, average='macro')))
print("Puntuación F1: {}".format(f1_score(Y_test, y_pred_rf, average='macro')))
# Out:
# Exactitud: 0.41
# Recall: 0.3818905819442185
# Precisión: 0.3952666315734027
# Puntuación F1: 0.38566498523827025

# %%
print(classification_report(Y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.45      0.28      0.34       156
#            2       0.34      0.34      0.34       237
#            3       0.28      0.21      0.24       315
#            4       0.35      0.38      0.36       395
#            5       0.51      0.62      0.56       472
#
#     accuracy                           0.40      1575
#    macro avg       0.39      0.37      0.37      1575
# weighted avg       0.39      0.40      0.39      1575

# %% [markdown]
# ## 2.5 Implementación Naive Bayes Complement (Abel Arismendy - 202020625)

# %%
from sklearn.naive_bayes import ComplementNB

model = ComplementNB(alpha=1)

y_data_1d = y_data.idxmax(axis=1)
X_train3, X_test3, Y_train3, Y_test3 = train_test_split(X_tf_nv, y_data_1d, test_size=0.2, random_state=0, stratify=y_data_1d)
X_train3 = np.asarray(X_train3)

model = model.fit(X_train3, Y_train3)

X_test3 = np.asarray(X_test3)

y_pred_nv = model.predict(X_test3)
cm = confusion_matrix(Y_test3, y_pred_nv)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=modelo.classes_)
disp.plot(cmap=plt.cm.Blues)

plt.show()

# %%
from sklearn.metrics import f1_score

print('Exactitud: %.2f' % accuracy_score(Y_test3, y_pred_nv))
print("Recall: {}".format(recall_score(Y_test3, y_pred_nv, average='macro')))
print("Precisión: {}".format(precision_score(Y_test3, y_pred_nv, average='macro')))
print("Puntuación F1: {}".format(f1_score(Y_test3, y_pred_nv, average='macro')))
# Out:
# Exactitud: 0.48
# Recall: 0.44617205900728746
# Precisión: 0.4631552943041856
# Puntuación F1: 0.44700800710711963

# %%
print(classification_report(Y_test3, y_pred_nv))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.49      0.37      0.42       156
#            2       0.42      0.43      0.42       237
#            3       0.41      0.28      0.33       315
#            4       0.43      0.40      0.42       395
#            5       0.56      0.76      0.65       472
#
#     accuracy                           0.48      1575
#    macro avg       0.46      0.45      0.45      1575
# weighted avg       0.47      0.48      0.47      1575

# %% [markdown]
# Busqueda de hiperparametros

# %%
# explicitly require this experimental feature
from sklearn.experimental import enable_halving_search_cv # noqa
# now you can import normally from model_selection
from sklearn.model_selection import HalvingGridSearchCV

# %%
model = ComplementNB()

# Split the data
y_data_1d = y_data.idxmax(axis=1)
X_train3, X_test3, Y_train3, Y_test3 = train_test_split(X_tf_nv, y_data_1d, test_size=0.2, random_state=0, stratify=y_data_1d)
X_train3 = np.asarray(X_train3)

# Define the parameter grid
param_grid = {'alpha': [i/100 for i in range(60, 111)]}

# Define the HalvingGridSearchCV
search = HalvingGridSearchCV(model, param_grid)
X_test3 = np.asarray(X_test3)

# Fit the model
search.fit(X_train3, Y_train3)

# Predict the test set results
y_pred_nv2 = search.predict(X_test3)

# Print the metrics
print('Exactitud: %.2f' % accuracy_score(Y_test3, y_pred_nv2))
print("Recall: {}".format(recall_score(Y_test3, y_pred_nv2, average='macro')))
print("Precisión: {}".format(precision_score(Y_test3, y_pred_nv2, average='macro')))
print("Puntuación F1: {}".format(f1_score(Y_test3, y_pred_nv2, average='macro')))
print(classification_report(Y_test3, y_pred_nv2))
# Out:
# Exactitud: 0.48
# Recall: 0.45068707318331863
# Precisión: 0.45874684508076014
# Puntuación F1: 0.44873257261742
#               precision    recall  f1-score   support
#
#            1       0.46      0.40      0.43       156
#            2       0.42      0.43      0.42       237
#            3       0.42      0.27      0.33       315
#            4       0.43      0.40      0.42       395
#            5       0.57      0.75      0.65       472
#
#     accuracy                           0.48      1575
#    macro avg       0.46      0.45      0.45      1575
# weighted avg       0.47      0.48      0.47      1575

# %%
search.best_params_
# Out:
# {'alpha': 0.62}

# %% [markdown]
# # 3. Resultados

# %% [markdown]
# Comparemos los resultados obtenidos por cada modelo por clase. Observamos que los 5 modelos implementados se comportan mejor para la clase 5.

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import f1_score
import numpy as np

# Calcula el puntaje F1 para cada clase para cada algoritmo
f1_scores = [f1_score(Y_test, y_pred, average=None) for y_pred in [y_pred_svc, y_pred_mlp, y_pred_lr, y_pred_rf, y_pred_nv2]]

# Crea una lista con los nombres de los algoritmos
algorithms = ['SVC', 'MLP', 'LR', 'RF', 'NB']

# Crea una lista con los nombres de las clases
classes = ['Clase 1', 'Clase 2', 'Clase 3', 'Clase 4', 'Clase 5']

# Crea una figura y un conjunto de subtramas
fig, ax = plt.subplots()

# Define una ubicación para las etiquetas del eje x
x = np.arange(len(classes))

# Define el ancho de las barras
bar_width = 0.15

# Para cada algoritmo, crea un gráfico de barras para cada clase
for i, (algorithm, f1_score) in enumerate(zip(algorithms, f1_scores)):
    ax.bar(x + i*bar_width, f1_score, width=bar_width, label=algorithm)

# Define las etiquetas del eje x y el título del gráfico
ax.set_xticks(x + bar_width / 2)
ax.set_xticklabels(classes)
ax.set_title('Puntaje F1 por Clase por Algoritmo')

# Agrega una leyenda
ax.legend()

ax.grid(axis='y')

# Muestra el gráfico
plt.show()

# %% [markdown]
# Comparamos las métricas de los 5 algoritmos implementados.
# De este modo, se puede observar que el algoritmo implementado con SVM (Máquinas de vectores de soporte) obtuvo mejores resultados

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score

# Calcula las métricas para cada algoritmo
metrics = {
    'Precision': [precision_score(Y_test, y_pred, average='macro') for y_pred in [y_pred_svc, y_pred_mlp, y_pred_lr, y_pred_rf, y_pred_nv2]],
    'Recall': [recall_score(Y_test, y_pred, average='macro') for y_pred in [y_pred_svc, y_pred_mlp, y_pred_lr, y_pred_rf, y_pred_nv2]],
    'F1 Score': [f1_score(Y_test, y_pred, average='macro') for y_pred in [y_pred_svc, y_pred_mlp, y_pred_lr, y_pred_rf, y_pred_nv2]],
    'Accuracy': [accuracy_score(Y_test, y_pred) for y_pred in [y_pred_svc, y_pred_mlp, y_pred_lr, y_pred_rf, y_pred_nv2]]
}

# Crea una lista con los nombres de los algoritmos
algorithms = ['SVC', 'MLP', 'LR', 'RF', 'NB']

# Define una ubicación para las etiquetas del eje x
x = np.arange(len(algorithms))

# Define el ancho de las barras
bar_width = 0.15

# Crea una figura y un conjunto de subtramas
fig, ax = plt.subplots(figsize=(15, 10))

# Para cada métrica, crea un gráfico de barras para cada algoritmo
for i, (metric, values) in enumerate(metrics.items()):
    ax.bar(x + i*bar_width, values, width=bar_width, label=metric)

# Define las etiquetas del eje x y el título del gráfico
ax.set_xticks(x + bar_width / 2)
ax.set_xticklabels(algorithms)
ax.set_title('Métricas por Algoritmo')
ax.set_ylim([0, .7])

ax.grid(axis='y')

# Agrega una leyenda
ax.legend()

# Muestra el gráfico
plt.show()

# %% [markdown]
# ## Identificación de palabras relevantes para la clasificación

# %% [markdown]
# Observamos que palabras tienen más importancia a la hora de tomar una decisión para clasificar una reseña, gracias al modelo de regresión lineal.

# %%
# Obtener los coeficientes del modelo (importancia de características)
feature_names = tf_idf.get_feature_names_out()
coefs = logreg.coef_

# Para cada clase, obtenemos las 10 características más importantes
for i in range(coefs.shape[0]):
    top10 = np.argpartition(coefs[i], -10)[-10:]
    print(f"Clase {i+1}: {[feature_names[j] for j in top10]}")
# Out:
# Clase 1: ['cover', 'mal', 'horrible', 'sucio', 'pesimo', 'romper', 'decir', 'peor', 'cucaracha', 'malo']
# Clase 2: ['carne', 'pedir', 'mal', 'parecer', 'agua', 'malo', 'pobre', 'no', 'caro', 'desear']
# Clase 3: ['informacion', 'bastante', 'buen', 'parecer', 'normal', 'regular', 'demasiado', 'embargo', 'falta', 'creer']
# Clase 4: ['mucho', 'duda', 'historia', 'habana', 'encontrar', 'comodo', 'excelente', 'estupendo', 'buen', 'disfrutar']
# Clase 5: ['ambiente', 'gran', 'super', 'espectacular', 'encanto', 'hermoso', 'increible', 'delicioso', 'gracias', 'excelente']

# %% [markdown]
# **1 Estrella:**
# - mal
# - horrible
# - sucio
# - pesimo
# - cucaracha
#
# Estás palabras sugieren que las reseñas de 1 estrella tienen que ver con la limpieza del lugar. Se le sugiere al negocio implementar estrategias para el control de plagas y una mejor limipieza en general.

# %% [markdown]
# **2 Estrellas:**
# - carne
# - agua
# - caro
# - malo
#
# Estás palabras sugieren que las reseñas de 2 estrellas fueron relacionadas con la comida y el precio del lugar.

# %% [markdown]
# **3 Estrellas:**
#
# - ‘informacion’
# - ‘parecer’
# - ‘normal’
# - ‘regular’
# - ‘demasiado’
# - ‘embargo’
# - ‘falta’
#
# Estas palabras sugieren que las reseñas de 3 estrellas pueden estar relacionadas con la cantidad y calidad de la información proporcionada, así como con la percepción general del lugar. Podría ser útil revisar la claridad y la precisión de la información proporcionada a los visitantes.

# %% [markdown]
# **4 Estrellas:**
#
# - ‘mucho’
# - ‘duda’
# - ‘historia’
# - ‘encontrar’
# - ‘comodo’
# - ‘excelente’
# - ‘estupendo’
# - ‘buen’
# - ‘disfrutar’
#
# Estas palabras sugieren que las reseñas de 4 estrellas están asociadas con una experiencia positiva en general. Las palabras como ‘historia’ y ‘disfrutar’ indican que los visitantes aprecian el contexto histórico y cultural del lugar.

# %% [markdown]
# **5 Estrellas:**
#
# - ‘ambiente’
# - ‘gran’
# - ‘super’
# - ‘espectacular’
# - ‘encanto’
# - ‘hermoso’
# - ‘increible’
# - ‘delicioso’
# - ‘gracias’
# - ‘excelente’
#
# Estas palabras sugieren que las reseñas de 5 estrellas están asociadas con una experiencia excepcional. Los visitantes parecen apreciar el ambiente, la belleza del lugar y la calidad de los servicios o productos ofrecidos.

# %% [markdown]
# # 4. Etiquetado de los datos

# %% [markdown]
# Cargar los datos a etiquetar

# %%
# Uso de la libreria pandas para la lectura de archivos
datos_sin_etiquetar=pd.read_csv('/content/particion_prueba_estudiantes.csv')

# %% [markdown]
# ### 4.1 Pre procesado de los datos

# %%
datos_sin_etiquetar['words'] = datos_sin_etiquetar['Review'].apply(word_tokenize)
datos_sin_etiquetar.head()
# Out:
#                                               Review
# 0  La primera noche nos encontramos en la habitac...  \
# 1  A una calle de catedral con platillos tradicio...
# 2  Porciones muy miserables\nAgua con sabor a clo...
# 3  Cartagena encanta. De todas las ciudades colon...
# 4  Ibamos con mucha ilusion de disfrutar el espec...
#
#                                                words
# 0  [La, primera, noche, nos, encontramos, en, la,...
# 1  [A, una, calle, de, catedral, con, platillos, ...
# 2  [Porciones, muy, miserables, Agua, con, sabor,...
# 3  [Cartagena, encanta, ., De, todas, las, ciudad...
# 4  [Ibamos, con, mucha, ilusion, de, disfrutar, e...

# %%
datos_sin_etiquetar.shape
# Out:
# (1750, 2)

# %%
datos_sin_etiquetar['words1']=datos_sin_etiquetar['words'].apply(preprocessing) #Aplica la eliminación del ruido

datos_sin_etiquetar.head()
# Out:
#                                               Review
# 0  La primera noche nos encontramos en la habitac...  \
# 1  A una calle de catedral con platillos tradicio...
# 2  Porciones muy miserables\nAgua con sabor a clo...
# 3  Cartagena encanta. De todas las ciudades colon...
# 4  Ibamos con mucha ilusion de disfrutar el espec...
#
#                                                words
# 0  [La, primera, noche, nos, encontramos, en, la,...  \
# 1  [A, una, calle, de, catedral, con, platillos, ...
# 2  [Porciones, muy, miserables, Agua, con, sabor,...
# 3  [Cartagena, encanta, ., De, todas, las, ciudad...
# 4  [Ibamos, con, mucha, ilusion, de, disfrutar, e...
#
#                                               words1
# 0  [la, primera, noche, encontramos, habitacion, ...
# 1  [a, calle, catedral, platillos, tradicionales,...
# 2  [porciones, miserables, agua, sabor, cloro, mu...
# 3  [cartagena, encanta, de, todas, ciudades, colo...
# 4  [ibamos, mucha, ilusion, disfrutar, espectacul...

# %%
datos_sin_etiquetar['words1'] = datos_sin_etiquetar['words1'].apply(lambda x: ' '.join(map(str, x)))

# %%
datos_sin_etiquetar['lemma'] = datos_sin_etiquetar['words1'].apply(lemmatize_spanish) #Aplica lematización y Eliminación de Prefijos y Sufijos.
datos_sin_etiquetar
# Out:
#                                                  Review
# 0     La primera noche nos encontramos en la habitac...  \
# 1     A una calle de catedral con platillos tradicio...
# 2     Porciones muy miserables\nAgua con sabor a clo...
# 3     Cartagena encanta. De todas las ciudades colon...
# 4     Ibamos con mucha ilusion de disfrutar el espec...
# ...                                                 ...
# 1745  Subir en funicular y bajar en teleferico fue u...
# 1746  La gente espera el lugar central en La Habana,...
# 1747  Todo excelente con el hotel: las albercas para...
# 1748  Nos detuvimos en un bocado antes de la puesta ...
# 1749  NO TENIA AGUA, el mantenimiento un desastre ( ...
#
#                                                   words
# 0     [La, primera, noche, nos, encontramos, en, la,...  \
# 1     [A, una, calle, de, catedral, con, platillos, ...
# 2     [Porciones, muy, miserables, Agua, con, sabor,...
# 3     [Cartagena, encanta, ., De, todas, las, ciudad...
# 4     [Ibamos, con, mucha, ilusion, de, disfrutar, e...
# ...                                                 ...
# 1745  [Subir, en, funicular, y, bajar, en, teleferic...
# 1746  [La, gente, espera, el, lugar, central, en, La...
# 1747  [Todo, excelente, con, el, hotel, :, las, albe...
# 1748  [Nos, detuvimos, en, un, bocado, antes, de, la...
# 1749  [NO, TENIA, AGUA, ,, el, mantenimiento, un, de...
#
#                                                  words1
# 0     la primera noche encontramos habitacion nido 5...  \
# 1     a calle catedral platillos tradicionales tipo ...
# 2     porciones miserables agua sabor cloro muy dist...
# 3     cartagena encanta de todas ciudades coloniales...
# 4     ibamos mucha ilusion disfrutar espectaculo luz...
# ...                                                 ...
# 1745  subir funicular bajar teleferico buena experie...
# 1746  la gente espera lugar central la habana fiesta...
# 1747  todo excelente hotel albercas ninos mejor aten...
# 1748  nos detuvimos bocado puesta sol no nadie resta...
# 1749  no tenia agua mantenimiento desastre mochila b...
#
#                                                   lemma
# 0     [el, primero, noche, encontrar, habitacion, ni...
# 1     [a, calle, catedral, platillo, tradicional, ti...
# 2     [porción, miserable, agua, sabor, cloro, mucho...
# 3     [cartagena, encantar, de, todo, ciudad, coloni...
# 4     [ir, mucho, ilusion, disfrutar, espectaculo, l...
# ...                                                 ...
# 1745  [subir, funicular, bajar, teleferico, buen, ex...
# 1746  [el, gente, esperar, lugar, central, el, haban...
# 1747  [todo, excelente, hotel, alberco, nino, mejor,...
# 1748  [yo, detener, bocado, puesto, sol, no, nadie, ...
# 1749  [no, tener, agua, mantenimiento, desastre, moc...
#
# [1750 rows x 4 columns]

# %%
datos_sin_etiquetar
# Out:
#                                                  Review
# 0     La primera noche nos encontramos en la habitac...  \
# 1     A una calle de catedral con platillos tradicio...
# 2     Porciones muy miserables\nAgua con sabor a clo...
# 3     Cartagena encanta. De todas las ciudades colon...
# 4     Ibamos con mucha ilusion de disfrutar el espec...
# ...                                                 ...
# 1745  Subir en funicular y bajar en teleferico fue u...
# 1746  La gente espera el lugar central en La Habana,...
# 1747  Todo excelente con el hotel: las albercas para...
# 1748  Nos detuvimos en un bocado antes de la puesta ...
# 1749  NO TENIA AGUA, el mantenimiento un desastre ( ...
#
#                                                   words
# 0     [La, primera, noche, nos, encontramos, en, la,...  \
# 1     [A, una, calle, de, catedral, con, platillos, ...
# 2     [Porciones, muy, miserables, Agua, con, sabor,...
# 3     [Cartagena, encanta, ., De, todas, las, ciudad...
# 4     [Ibamos, con, mucha, ilusion, de, disfrutar, e...
# ...                                                 ...
# 1745  [Subir, en, funicular, y, bajar, en, teleferic...
# 1746  [La, gente, espera, el, lugar, central, en, La...
# 1747  [Todo, excelente, con, el, hotel, :, las, albe...
# 1748  [Nos, detuvimos, en, un, bocado, antes, de, la...
# 1749  [NO, TENIA, AGUA, ,, el, mantenimiento, un, de...
#
#                                                  words1
# 0     la primera noche encontramos habitacion nido 5...  \
# 1     a calle catedral platillos tradicionales tipo ...
# 2     porciones miserables agua sabor cloro muy dist...
# 3     cartagena encanta de todas ciudades coloniales...
# 4     ibamos mucha ilusion disfrutar espectaculo luz...
# ...                                                 ...
# 1745  subir funicular bajar teleferico buena experie...
# 1746  la gente espera lugar central la habana fiesta...
# 1747  todo excelente hotel albercas ninos mejor aten...
# 1748  nos detuvimos bocado puesta sol no nadie resta...
# 1749  no tenia agua mantenimiento desastre mochila b...
#
#                                                   lemma
# 0     [el, primero, noche, encontrar, habitacion, ni...
# 1     [a, calle, catedral, platillo, tradicional, ti...
# 2     [porción, miserable, agua, sabor, cloro, mucho...
# 3     [cartagena, encantar, de, todo, ciudad, coloni...
# 4     [ir, mucho, ilusion, disfrutar, espectaculo, l...
# ...                                                 ...
# 1745  [subir, funicular, bajar, teleferico, buen, ex...
# 1746  [el, gente, esperar, lugar, central, el, haban...
# 1747  [todo, excelente, hotel, alberco, nino, mejor,...
# 1748  [yo, detener, bocado, puesto, sol, no, nadie, ...
# 1749  [no, tener, agua, mantenimiento, desastre, moc...
#
# [1750 rows x 4 columns]

# %%
datos_sin_etiquetar['lemma_2'] = datos_sin_etiquetar['lemma'].apply(lambda x: [word for word in x if word not in default_stopwords])

# %%
# Eliminar números
datos_sin_etiquetar['lemma_2'] = datos_sin_etiquetar['lemma_2'].apply(lambda x: [word for word in x if not word.isdigit()])

# %%
datos_sin_etiquetar
# Out:
#                                                  Review
# 0     La primera noche nos encontramos en la habitac...  \
# 1     A una calle de catedral con platillos tradicio...
# 2     Porciones muy miserables\nAgua con sabor a clo...
# 3     Cartagena encanta. De todas las ciudades colon...
# 4     Ibamos con mucha ilusion de disfrutar el espec...
# ...                                                 ...
# 1745  Subir en funicular y bajar en teleferico fue u...
# 1746  La gente espera el lugar central en La Habana,...
# 1747  Todo excelente con el hotel: las albercas para...
# 1748  Nos detuvimos en un bocado antes de la puesta ...
# 1749  NO TENIA AGUA, el mantenimiento un desastre ( ...
#
#                                                   words
# 0     [La, primera, noche, nos, encontramos, en, la,...  \
# 1     [A, una, calle, de, catedral, con, platillos, ...
# 2     [Porciones, muy, miserables, Agua, con, sabor,...
# 3     [Cartagena, encanta, ., De, todas, las, ciudad...
# 4     [Ibamos, con, mucha, ilusion, de, disfrutar, e...
# ...                                                 ...
# 1745  [Subir, en, funicular, y, bajar, en, teleferic...
# 1746  [La, gente, espera, el, lugar, central, en, La...
# 1747  [Todo, excelente, con, el, hotel, :, las, albe...
# 1748  [Nos, detuvimos, en, un, bocado, antes, de, la...
# 1749  [NO, TENIA, AGUA, ,, el, mantenimiento, un, de...
#
#                                                  words1
# 0     la primera noche encontramos habitacion nido 5...  \
# 1     a calle catedral platillos tradicionales tipo ...
# 2     porciones miserables agua sabor cloro muy dist...
# 3     cartagena encanta de todas ciudades coloniales...
# 4     ibamos mucha ilusion disfrutar espectaculo luz...
# ...                                                 ...
# 1745  subir funicular bajar teleferico buena experie...
# 1746  la gente espera lugar central la habana fiesta...
# 1747  todo excelente hotel albercas ninos mejor aten...
# 1748  nos detuvimos bocado puesta sol no nadie resta...
# 1749  no tenia agua mantenimiento desastre mochila b...
#
#                                                   lemma
# 0     [el, primero, noche, encontrar, habitacion, ni...  \
# 1     [a, calle, catedral, platillo, tradicional, ti...
# 2     [porción, miserable, agua, sabor, cloro, mucho...
# 3     [cartagena, encantar, de, todo, ciudad, coloni...
# 4     [ir, mucho, ilusion, disfrutar, espectaculo, l...
# ...                                                 ...
# 1745  [subir, funicular, bajar, teleferico, buen, ex...
# 1746  [el, gente, esperar, lugar, central, el, haban...
# 1747  [todo, excelente, hotel, alberco, nino, mejor,...
# 1748  [yo, detener, bocado, puesto, sol, no, nadie, ...
# 1749  [no, tener, agua, mantenimiento, desastre, moc...
#
#                                                 lemma_2
# 0     [primero, noche, encontrar, habitacion, nido, ...
# 1     [calle, catedral, platillo, tradicional, tipo,...
# 2     [porción, miserable, agua, sabor, cloro, mucho...
# 3     [cartagena, encantar, todo, ciudad, colonial, ...
# 4     [ir, mucho, ilusion, disfrutar, espectaculo, l...
# ...                                                 ...
# 1745  [subir, funicular, bajar, teleferico, buen, ex...
# 1746  [gente, esperar, lugar, central, habana, fiest...
# 1747  [todo, excelente, hotel, alberco, nino, mejor,...
# 1748  [detener, bocado, puesto, sol, no, nadie, rest...
# 1749  [no, tener, agua, mantenimiento, desastre, moc...
#
# [1750 rows x 5 columns]

# %%
datos_sin_etiquetar['datos'] = datos_sin_etiquetar['lemma_2'].apply(lambda x: ' '.join(map(str, x)))
X_sin_tag = datos_sin_etiquetar['datos']

# %%
X_tf_idf_sin_tag = tf_idf.transform(X_sin_tag)
print(X_tf_idf_sin_tag.shape)
# Out:
# (1750, 16190)

# %% [markdown]
# ## 4.2 Etiquetado usando el modelo entrenado con SVM

# %%
# load
with open('model.pkl', 'rb') as f:
    clf_final = pickle.load(f)


y_tag = clf_final.predict(X_tf_idf_sin_tag)

# %%
datos_sin_etiquetar['Class'] = y_tag
datos_sin_etiquetar
# Out:
#                                                  Review
# 0     La primera noche nos encontramos en la habitac...  \
# 1     A una calle de catedral con platillos tradicio...
# 2     Porciones muy miserables\nAgua con sabor a clo...
# 3     Cartagena encanta. De todas las ciudades colon...
# 4     Ibamos con mucha ilusion de disfrutar el espec...
# ...                                                 ...
# 1745  Subir en funicular y bajar en teleferico fue u...
# 1746  La gente espera el lugar central en La Habana,...
# 1747  Todo excelente con el hotel: las albercas para...
# 1748  Nos detuvimos en un bocado antes de la puesta ...
# 1749  NO TENIA AGUA, el mantenimiento un desastre ( ...
#
#                                                   words
# 0     [La, primera, noche, nos, encontramos, en, la,...  \
# 1     [A, una, calle, de, catedral, con, platillos, ...
# 2     [Porciones, muy, miserables, Agua, con, sabor,...
# 3     [Cartagena, encanta, ., De, todas, las, ciudad...
# 4     [Ibamos, con, mucha, ilusion, de, disfrutar, e...
# ...                                                 ...
# 1745  [Subir, en, funicular, y, bajar, en, teleferic...
# 1746  [La, gente, espera, el, lugar, central, en, La...
# 1747  [Todo, excelente, con, el, hotel, :, las, albe...
# 1748  [Nos, detuvimos, en, un, bocado, antes, de, la...
# 1749  [NO, TENIA, AGUA, ,, el, mantenimiento, un, de...
#
#                                                  words1
# 0     la primera noche encontramos habitacion nido 5...  \
# 1     a calle catedral platillos tradicionales tipo ...
# 2     porciones miserables agua sabor cloro muy dist...
# 3     cartagena encanta de todas ciudades coloniales...
# 4     ibamos mucha ilusion disfrutar espectaculo luz...
# ...                                                 ...
# 1745  subir funicular bajar teleferico buena experie...
# 1746  la gente espera lugar central la habana fiesta...
# 1747  todo excelente hotel albercas ninos mejor aten...
# 1748  nos detuvimos bocado puesta sol no nadie resta...
# 1749  no tenia agua mantenimiento desastre mochila b...
#
#                                                   lemma
# 0     [el, primero, noche, encontrar, habitacion, ni...  \
# 1     [a, calle, catedral, platillo, tradicional, ti...
# 2     [porción, miserable, agua, sabor, cloro, mucho...
# 3     [cartagena, encantar, de, todo, ciudad, coloni...
# 4     [ir, mucho, ilusion, disfrutar, espectaculo, l...
# ...                                                 ...
# 1745  [subir, funicular, bajar, teleferico, buen, ex...
# 1746  [el, gente, esperar, lugar, central, el, haban...
# 1747  [todo, excelente, hotel, alberco, nino, mejor,...
# 1748  [yo, detener, bocado, puesto, sol, no, nadie, ...
# 1749  [no, tener, agua, mantenimiento, desastre, moc...
#
#                                                 lemma_2
# 0     [primero, noche, encontrar, habitacion, nido, ...  \
# 1     [calle, catedral, platillo, tradicional, tipo,...
# 2     [porción, miserable, agua, sabor, cloro, mucho...
# 3     [cartagena, encantar, todo, ciudad, colonial, ...
# 4     [ir, mucho, ilusion, disfrutar, espectaculo, l...
# ...                                                 ...
# 1745  [subir, funicular, bajar, teleferico, buen, ex...
# 1746  [gente, esperar, lugar, central, habana, fiest...
# 1747  [todo, excelente, hotel, alberco, nino, mejor,...
# 1748  [detener, bocado, puesto, sol, no, nadie, rest...
# 1749  [no, tener, agua, mantenimiento, desastre, moc...
#
#                                                   datos  Class
# 0     primero noche encontrar habitacion nido cucara...      1
# 1     calle catedral platillo tradicional tipo gourm...      5
# 2     porción miserable agua sabor cloro mucho distr...      2
# 3     cartagena encantar todo ciudad colonial visita...      5
# 4     ir mucho ilusion disfrutar espectaculo luz son...      3
# ...                                                 ...    ...
# 1745  subir funicular bajar teleferico buen experien...      5
# 1746  gente esperar lugar central habana fiesta naci...      3
# 1747  todo excelente hotel alberco nino mejor atenci...      5
# 1748  detener bocado puesto sol no nadie restaurante...      3
# 1749  no tener agua mantenimiento desastre mochila b...      1
#
# [1750 rows x 7 columns]

# %% [markdown]
# Exportamos los datos.

# %%
datos_sin_etiquetar[['Review', 'Class']].to_csv('resultados_etiquetados.csv', index=False)
